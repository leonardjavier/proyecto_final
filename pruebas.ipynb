# %% [markdown]
# # analisis de datos

# %%
# librerias
import pandas as pd

# %%
# carga el data frame
df = pd.read_csv("df_restaurantes")

# %%
# presentacion de los datos 
df
# Out:
#     userID  smoker dress_preference     drink_level  birth_year      activity  \
# 0    U1001   False         informal      abstemious        1989       student
# 1    U1002   False         informal      abstemious        1990       student
# 2    U1003   False           formal  social drinker        1989       student
# 3    U1004   False         informal      abstemious        1940  professional
# 4    U1005   False    no preference      abstemious        1992       student
# ..     ...     ...              ...             ...         ...           ...
# 122  U1134   False    no preference  casual drinker        1991       student
# 123  U1135   False         informal  casual drinker        1988       student
# 124  U1136    True    no preference  social drinker        1990       student
# 125  U1137   False           formal  social drinker        1989       student
# 126  U1138   False           formal  social drinker        1991       student
#
# ...

# %%
# informacion del data frame
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   userID            127 non-null    object
#  1   smoker            127 non-null    bool
#  2   dress_preference  127 non-null    object
#  3   drink_level       127 non-null    object
#  4   birth_year        127 non-null    int64
#  5   activity          127 non-null    object
#  6   color             127 non-null    object
#  7   budget            127 non-null    object
#  8   height            127 non-null    float64
#  9   latitude          127 non-null    float64
#  10  longitude         127 non-null    float64
# dtypes: bool(1), float64(3), int64(1), object(6)
# memory usage: 10.2+ KB
# None

# %%
# descripcion del data frame
print(df.describe())
# Out:
#         birth_year      height    latitude   longitude
# count   127.000000  127.000000  127.000000  127.000000
# mean   1985.259843    1.679528   21.768583 -100.289015
# std      13.554834    0.113164    1.567515    0.870284
# min    1930.000000    1.200000   18.813348 -101.054680
# 25%    1987.000000    1.600000   22.125695 -100.980902
# 50%    1989.000000    1.690000   22.150310 -100.937321
# 75%    1991.000000    1.750000   22.184169  -99.183252
# max    1994.000000    2.000000   23.771030  -99.067106

# %% [markdown]
# # graficos del data frame

# %%
# amplitud de los restaurantes 
histograma = df.height.plot.hist()
histograma
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
# crecimiento de los restaurates 
df.plot.scatter(y="height",x="birth_year")
# Out:
# <AxesSubplot: xlabel='birth_year', ylabel='height'>

# %%
# nivel de bebida
bebidas_restaurantes = df.drink_level.value_counts()
bebidas_restaurantes.plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='drink_level'>

# %%
# colores de los restaurantes 
color_del_restaurantes = df.color.value_counts()
color_del_restaurantes = color_del_restaurantes.sort_values(ascending=True)
color_del_restaurantes.plot.bar()
# Out:
# <AxesSubplot: >

# %%
# Restaurantes de los cuales te permiten fumar
fumadores_en_restaurantes = df.smoker.value_counts()
fumadores_en_restaurantes.plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='smoker'>

# %%
# actividades 
bebida = df.activity.value_counts()
bebida = bebida.sort_values(ascending=True)
bebida.plot.bar()
# Out:
# <AxesSubplot: >

# %%
# preferencias de vestimentas
preferencias = df.dress_preference.value_counts()
preferencias.plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='dress_preference'>
